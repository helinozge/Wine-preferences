# %%
import pandas as pd
df = pd.read_csv("wines_SPA.CSV")

df
# Out:
#                     winery             wine  year  rating  num_reviews  \
# 0            Teso La Monja            Tinto  2013     4.9           58
# 1                   Artadi    Vina El Pison  2018     4.9           31
# 2             Vega Sicilia            Unico  2009     4.8         1793
# 3             Vega Sicilia            Unico  1999     4.8         1705
# 4             Vega Sicilia            Unico  1996     4.8         1309
# ...                    ...              ...   ...     ...          ...
# 7495               Contino          Reserva  2016     4.2          392
# 7496  Conreria d'Scala Dei    Les Brugueres  2018     4.2          390
# 7497           Mustiguillo  Finca Terrerazo  2017     4.2          390
# 7498           Matarromera     Gran Reserva  2011     4.2          389
# 7499              Sei Solo         Preludio  2016     4.2          388
#
#      country            region   price                  type  body  acidity
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# Identify duplicated rows
duplicates = df.duplicated()

# Display duplicated rows
print("\nDuplicated Rows (identifies duplicates beyond the first occurrence):")
print(df[duplicates])

# Count total number of duplicate rows
total_duplicates = duplicates.sum()
print(f"\nTotal number of duplicate rows: {total_duplicates}")
# Out:
# Duplicated Rows (identifies duplicates beyond the first occurrence):
#                     winery             wine  year  rating  num_reviews  \
# 1800        Bodega Tameran       Marmajuelo  2020     4.3           27
# 2036        Ramon do Casar       Treixadura  2020     4.2          407
# 2039              Binigrau           Nounat  2020     4.2          404
# 2050          La Vicalanda          Reserva  2015     4.2          420
# 2051       Enrique Mendoza       Santa Rosa  2017     4.2          420
# ...                    ...              ...   ...     ...          ...
# 7495               Contino          Reserva  2016     4.2          392
# 7496  Conreria d'Scala Dei    Les Brugueres  2018     4.2          390
# 7497           Mustiguillo  Finca Terrerazo  2017     4.2          390
# 7498           Matarromera     Gran Reserva  2011     4.2          389
# 7499              Sei Solo         Preludio  2016     4.2          388
#
# ...

# %%
df_cleaned = df.drop_duplicates()

# Display the cleaned DataFrame
print("\nDataFrame after dropping duplicates (keeping first occurrence):")
print(df_cleaned)
# Out:
# DataFrame after dropping duplicates (keeping first occurrence):
#                   winery             wine  year  rating  num_reviews country  \
# 0          Teso La Monja            Tinto  2013     4.9           58  Espana
# 1                 Artadi    Vina El Pison  2018     4.9           31  Espana
# 2           Vega Sicilia            Unico  2009     4.8         1793  Espana
# 3           Vega Sicilia            Unico  1999     4.8         1705  Espana
# 4           Vega Sicilia            Unico  1996     4.8         1309  Espana
# ...                  ...              ...   ...     ...          ...     ...
# 2046         Mustiguillo  Finca Terrerazo  2017     4.2          390  Espana
# 2047         Matarromera     Gran Reserva  2011     4.2          389  Espana
# 2048            Sei Solo         Preludio  2016     4.2          388  Espana
# 2049  Vinedos de Paganos       El Puntido  2005     4.2          384  Espana
# ...

# %%
df_cleaned
# Out:
#                   winery             wine  year  rating  num_reviews country  \
# 0          Teso La Monja            Tinto  2013     4.9           58  Espana
# 1                 Artadi    Vina El Pison  2018     4.9           31  Espana
# 2           Vega Sicilia            Unico  2009     4.8         1793  Espana
# 3           Vega Sicilia            Unico  1999     4.8         1705  Espana
# 4           Vega Sicilia            Unico  1996     4.8         1309  Espana
# ...                  ...              ...   ...     ...          ...     ...
# 2046         Mustiguillo  Finca Terrerazo  2017     4.2          390  Espana
# 2047         Matarromera     Gran Reserva  2011     4.2          389  Espana
# 2048            Sei Solo         Preludio  2016     4.2          388  Espana
# 2049  Vinedos de Paganos       El Puntido  2005     4.2          384  Espana
# 6100   Remirez de Ganuza     Rioja Blanco  2017     4.2          421  Espana
#
# ...

# %%
unique_values = df_cleaned['type'].unique()

# Display the unique values
print("\nUnique values in 'type' column:")
print(unique_values)
# Out:
# Unique values in 'type' column:
# ['Toro Red' 'Tempranillo' 'Ribera Del Duero Red' 'Pedro Ximenez' 'Red'
#  'Sherry' 'Priorat Red' 'Rioja Red' 'Rioja White' 'Grenache' nan 'Cava'
#  'Verdejo' 'Syrah' 'Monastrell' 'Mencia' 'Sparkling' 'Montsant Red'
#  'Albarino' 'Chardonnay' 'Cabernet Sauvignon' 'Sauvignon Blanc']

# %%
null_type = df_cleaned['type'].isnull()

# Display rows with null values in the 'type' column
print("\nRows with null values in the 'type' column:")
print(df_cleaned[null_type])
# Out:
# Rows with null values in the 'type' column:
#                       winery                                wine  year  \
# 120            Finca Moncloa                    Tintilla de Rota  2016
# 147          Rafael Palacios           Sorte O Soro Val do Bibei  2019
# 156     Gutierrez de la Vega  Recondita Armonia Monastrell Dulce  1987
# 254      Costers del Siurana                      Dolc de L'Obac  2006
# 288   Francisco Garcia Perez          Adega do Moucho Treixadura  2017
# ...                      ...                                 ...   ...
# 1934                 Gramona                             Gessami  2020
# 1982             Emilio Moro                  La Revelia Godello  2018
# 1995                Culebron              Fondillon Gran Reserva  1964
# 2011          Ramon do Casar                          Treixadura  2020
# 2014                Binigrau                              Nounat  2020
#
# ...

# %%
unique_values = df_cleaned['wine'].unique()

# Display the unique values
print("\nUnique values in 'wine' column:")
print(unique_values)
print(len(unique_values))
# Out:
# Unique values in 'wine' column:
# ['Tinto' 'Vina El Pison' 'Unico' 'Unico Reserva Especial Edicion'
#  'El Anejon' 'Don PX Convento Seleccion' 'Cuesta de Las Liebres' 'El Nido'
#  'Toneles Moscatel' 'Pingus' 'Don PX Pedro Ximenez'
#  "L'Ermita Velles Vinyes Priorat" 'Vatan Arena Tinta de Toro'
#  'Ribera Del Duero Gran Reserva 12 Anos' 'Pesus Ribera del Duero' 'Magico'
#  'La Faraona Bierzo (Corullon)' 'Gran Reserva 890' 'Valbuena 5o'
#  'Castillo Ygay Gran Reserva Especial Blanco' 'La Nieta'
#  'Malleolus de Valderramiro' 'Malleolus de Sanchomartin' 'Alabaster'
#  'La Mula de la Quietud' 'Terreus Paraje de Cueva Baja' 'Contador Rioja'
#  'Maria Remirez de Ganuza' 'Cartago Paraje de Pozo'
#  'Parcela El Picon Tinto' 'Termanthia' 'Clon De La Familia'
#  'Aquilon Garnacha' 'Quinon de Valmira' '1902 Centenary Carignan Priorat'
#  'Tintilla de Rota' 'Cirsion Rioja' 'Cami Pesseroles' "Turo d'en Mota"
#  'Priorat' 'Reliquia Palo Cortado Sherry' 'Anada Palo Cortado 1987'
# ...

# %%
null_type = df_cleaned['wine'].isnull()

# Display rows with null values in the 'type' column
print("\nRows with null values in the 'wine' column:")
print(df_cleaned[null_type])
# Out:
# Rows with null values in the 'wine' column:
# Empty DataFrame
# Columns: [winery, wine, year, rating, num_reviews, country, region, price, type, body, acidity]
# Index: []

# %%
unique_values = df_cleaned['winery'].unique()

# Display the unique values
print("\nUnique values in 'winery' column:")
print(unique_values)
print("\nNumber of unique values in 'winery' column:")
print(len(unique_values))
# Out:
# Unique values in 'winery' column:
# ['Teso La Monja' 'Artadi' 'Vega Sicilia' 'Pago de Carraovejas'
#  'Toro Albala' 'Bodegas El Nido' 'Valdespino' 'Dominio de Pingus'
#  'Alvaro Palacios' 'Ordonez' 'Bodegas Valduero' 'Vina Sastre'
#  'Sierra Cantabria' 'Descendientes de J. Palacios' 'La Rioja Alta'
#  'Marques de Murrieta' 'Vinedos de Paganos' 'Emilio Moro'
#  'Quinta de la Quietud' 'Bodegas Mauro' 'Bodega Contador (Benjamin Romeo)'
#  'Remirez de Ganuza' 'Bodegas San Roman' 'Pago de Los Capellanes'
#  'Bodega Numanthia' 'Alto Moncayo' 'Mas Doix' 'Finca Moncloa'
#  'Bodegas Roda' 'Martinet' 'Recaredo' 'Clos Erasmus' 'Barbadillo'
#  'Gonzalez-Byass' 'Bodegas Amaren' 'Alvear' 'Equipo Navazos' 'Morca'
#  'Territorio Luthier' 'Rafael Palacios' 'Terra Remota'
#  'Dehesa de Los Canonigos' 'Miguel Merino' 'Gutierrez de la Vega' 'Alion'
#  'Aalto' 'Carmelo Rodero' 'Dominio del Bendito' "Mas d'en Gil"
#  'Casa Castillo' 'Matarromera' 'Nin-Ortiz' 'Vinas del Vero'
# ...

# %%
null_type = df_cleaned['winery'].isnull()

# Display rows with null values in the 'type' column
print("\nRows with null values in the 'winery' column:")
print(df_cleaned[null_type])
# Out:
# Rows with null values in the 'winery' column:
# Empty DataFrame
# Columns: [winery, wine, year, rating, num_reviews, country, region, price, type, body, acidity]
# Index: []

# %%
unique_values = df_cleaned['price'].unique()

# Display the unique values
print("\nUnique values in 'price' column:")
print(unique_values)
print(len(unique_values))
# Out:
# Unique values in 'price' column:
# [995.   313.5  324.95 ...  16.76  24.45  31.63]
# 1292

# %%
max_price = df_cleaned['price'].max()

# Display the maximum price
print("\nMaximum price:")
print(max_price)
# Out:
# Maximum price:
# 3119.08

# %%
min_price = df_cleaned['price'].min()

# Display the maximum price
print("\nMinimum price:")
print(min_price)
# Out:
# Minimum price:
# 4.99

# %%
null_type = df_cleaned['price'].isnull()

# Display rows with null values in the 'type' column
print("\nRows with null values in the 'price' column:")
print(df_cleaned[null_type])
# Out:
# Rows with null values in the 'price' column:
# Empty DataFrame
# Columns: [winery, wine, year, rating, num_reviews, country, region, price, type, body, acidity]
# Index: []

# %%
unique_values = df_cleaned['year'].unique()

# Display the unique values
print("\nUnique values in 'year' column:")
print(unique_values)
# Out:
# Unique values in 'year' column:
# ['2013' '2018' '2009' '1999' '1996' '1998' '2010' '1995' '2015' '2011'
#  '2016' '1970' '1946' '1962' '2019' '2004' 'N.V.' '1931' '1979' '2005'
#  '2020' '2014' '1985' '1929' '2007' '2012' '2017' '2008' nan '2006' '2000'
#  '2003' '2002' '1991' '1994' '1990' '1989' '1987' '1986' '1981' '2001'
#  '1968' '1964' '1982' '1974' '1983' '1955' '1980' '1972' '1953' '1958'
#  '1942' '1965' '1992' '1973' '1997' '1967' '1975' '1910' '1961' '1954'
#  '1988' '1969' '1951' '1928' '1976' '1949' '2021' '1959' '1922' '1978'
#  '1925']

# %%
unique_values = df_cleaned['region'].unique()

# Display the unique values
print("\nUnique values in 'region' column:")
print(unique_values)
print(len(unique_values))
# Out:
# Unique values in 'region' column:
# ['Toro' 'Vino de Espana' 'Ribera del Duero' 'Montilla-Moriles' 'Jumilla'
#  'Jerez-Xeres-Sherry' 'Priorato' 'Rioja' 'Bierzo' 'Castilla y Leon'
#  'Campo de Borja' 'Cadiz' 'Cava' 'Jerez Palo Cortado' 'Manzanilla'
#  'Valdeorras' 'Emporda' 'Rioja Alta' 'Alicante' 'Somontano'
#  'Dominio de Valdepusa' 'Ribeiro' 'Mallorca' 'Yecla' 'Cigales'
#  'Utiel-Requena' 'Navarra' 'Rioja Alavesa' 'Costers del Segre'
#  'Sardon de Duero' 'Malaga' 'Cataluna' 'Rueda' 'Jerez Pedro Ximenes (PX)'
#  'Montsant' 'Conca de Barbera' 'Rias Baixas' 'Jerez Amontillado'
#  'Tierra del Vino de Zamora' 'Penedes' 'Dehesa del Carrizal' 'Madrid'
#  'Carinena' 'Condado de Huelva' 'Almansa' 'Jerez Cream' 'Valencia'
#  'Sierras de Malaga' 'Ribeira Sacra' 'El Terrerazo' 'Jerez Oloroso'
#  'Castilla' 'Alella' 'Pla i Llevant' 'Pla de Bages' 'Pago Calzadilla'
#  'Andalucia' 'Monterrei' 'Ribera del Gallego-Cinco Villas' 'Aragon'
# ...

# %%
unique_values = df_cleaned['acidity'].unique()

# Display the unique values
print("\nUnique values in 'acidity' column:")
print(unique_values)
print(len(unique_values))
# Out:
# Unique values in 'acidity' column:
# [ 3.  2.  1. nan]
# 4

# %%
null_type = df_cleaned['acidity'].isnull()

# Display rows with null values in the 'type' column
print("\nRows with null values in the 'acidity' column:")
print(df_cleaned[null_type])
# Out:
# Rows with null values in the 'acidity' column:
#                       winery                                wine  year  \
# 120            Finca Moncloa                    Tintilla de Rota  2016
# 147          Rafael Palacios           Sorte O Soro Val do Bibei  2019
# 156     Gutierrez de la Vega  Recondita Armonia Monastrell Dulce  1987
# 254      Costers del Siurana                      Dolc de L'Obac  2006
# 288   Francisco Garcia Perez          Adega do Moucho Treixadura  2017
# ...                      ...                                 ...   ...
# 2021             Mustiguillo                     Finca Terrerazo  2017
# 2022             Matarromera                        Gran Reserva  2011
# 2023                Sei Solo                            Preludio  2016
# 2024      Vinedos de Paganos                          El Puntido  2005
# 6100       Remirez de Ganuza                        Rioja Blanco  2017
#
#       rating  num_reviews country            region      price  \
# ...

# %%
null_type = df_cleaned['body'].isnull()

# Display rows with null values in the 'type' column
print("\nRows with null values in the 'acidity' column:")
print(df_cleaned[null_type])
print(len(null_type))
# Out:
# Rows with null values in the 'acidity' column:
#                       winery                                wine  year  \
# 120            Finca Moncloa                    Tintilla de Rota  2016
# 147          Rafael Palacios           Sorte O Soro Val do Bibei  2019
# 156     Gutierrez de la Vega  Recondita Armonia Monastrell Dulce  1987
# 254      Costers del Siurana                      Dolc de L'Obac  2006
# 288   Francisco Garcia Perez          Adega do Moucho Treixadura  2017
# ...                      ...                                 ...   ...
# 2021             Mustiguillo                     Finca Terrerazo  2017
# 2022             Matarromera                        Gran Reserva  2011
# 2023                Sei Solo                            Preludio  2016
# 2024      Vinedos de Paganos                          El Puntido  2005
# 6100       Remirez de Ganuza                        Rioja Blanco  2017
#
#       rating  num_reviews country            region      price  \
# ...

# %%
# Fill NaN values in the 'acidity' column with "unknown"
df_cleaned['body'] = df_cleaned['body'].fillna('unknown')

# Display the DataFrame after filling NaN values
print("\nDataFrame after filling NaN values in 'body' with 'unknown':")
print(df_cleaned)
# Out:
# DataFrame after filling NaN values in 'body' with 'unknown':
#                   winery             wine  year  rating  num_reviews country  \
# 0          Teso La Monja            Tinto  2013     4.9           58  Espana
# 1                 Artadi    Vina El Pison  2018     4.9           31  Espana
# 2           Vega Sicilia            Unico  2009     4.8         1793  Espana
# 3           Vega Sicilia            Unico  1999     4.8         1705  Espana
# 4           Vega Sicilia            Unico  1996     4.8         1309  Espana
# ...                  ...              ...   ...     ...          ...     ...
# 2046         Mustiguillo  Finca Terrerazo  2017     4.2          390  Espana
# 2047         Matarromera     Gran Reserva  2011     4.2          389  Espana
# 2048            Sei Solo         Preludio  2016     4.2          388  Espana
# 2049  Vinedos de Paganos       El Puntido  2005     4.2          384  Espana
# ...

# %%
# Fill NaN values in the 'acidity' column with "unknown"
df_cleaned['acidity'] = df_cleaned['acidity'].fillna('unknown')

# Display the DataFrame after filling NaN values
print("\nDataFrame after filling NaN values in 'acidity' with 'unknown':")
print(df_cleaned)
# Out:
# DataFrame after filling NaN values in 'acidity' with 'unknown':
#                   winery             wine  year  rating  num_reviews country  \
# 0          Teso La Monja            Tinto  2013     4.9           58  Espana
# 1                 Artadi    Vina El Pison  2018     4.9           31  Espana
# 2           Vega Sicilia            Unico  2009     4.8         1793  Espana
# 3           Vega Sicilia            Unico  1999     4.8         1705  Espana
# 4           Vega Sicilia            Unico  1996     4.8         1309  Espana
# ...                  ...              ...   ...     ...          ...     ...
# 2046         Mustiguillo  Finca Terrerazo  2017     4.2          390  Espana
# 2047         Matarromera     Gran Reserva  2011     4.2          389  Espana
# 2048            Sei Solo         Preludio  2016     4.2          388  Espana
# 2049  Vinedos de Paganos       El Puntido  2005     4.2          384  Espana
# ...

# %%
null_type = df_cleaned['year'].isnull()

# Display rows with null values in the 'type' column
print("\nRows with null values in the 'year' column:")
print(df_cleaned[null_type])
# Out:
# Rows with null values in the 'year' column:
#            winery                            wine year  rating  num_reviews  \
# 46   Vega Sicilia  Unico Reserva Especial Edicion  NaN     4.7        12421
# 851      La Unica                  Fourth Edition  NaN     4.4          131
#
#     country            region  price                  type body acidity
# 46   Espana  Ribera del Duero  423.5  Ribera Del Duero Red  5.0     3.0
# 851  Espana    Vino de Espana   40.0           Tempranillo  4.0     2.0

# %%
# Convert 'year' column to numeric, coercing errors to NaN
df_cleaned['year'] = pd.to_numeric(df_cleaned['year'], errors='coerce')

# Calculate the mean of the numeric 'year' column
year_mean = df_cleaned['year'].mean()

# Fill NaN values in the 'year' column with the mean
df_cleaned['year'] = df_cleaned['year'].fillna(year_mean)

# Display the DataFrame after filling NaN values
print("\nDataFrame after filling NaN values in 'year' with the mean:")
print(df_cleaned)
# Out:
# DataFrame after filling NaN values in 'year' with the mean:
#                   winery             wine    year  rating  num_reviews  \
# 0          Teso La Monja            Tinto  2013.0     4.9           58
# 1                 Artadi    Vina El Pison  2018.0     4.9           31
# 2           Vega Sicilia            Unico  2009.0     4.8         1793
# 3           Vega Sicilia            Unico  1999.0     4.8         1705
# 4           Vega Sicilia            Unico  1996.0     4.8         1309
# ...                  ...              ...     ...     ...          ...
# 2046         Mustiguillo  Finca Terrerazo  2017.0     4.2          390
# 2047         Matarromera     Gran Reserva  2011.0     4.2          389
# 2048            Sei Solo         Preludio  2016.0     4.2          388
# 2049  Vinedos de Paganos       El Puntido  2005.0     4.2          384
# 6100   Remirez de Ganuza     Rioja Blanco  2017.0     4.2          421
#
# ...

# %%
null_type = df_cleaned['year'].isnull()

# Display rows with null values in the 'type' column
print("\nRows with null values in the 'year' column:")
print(df_cleaned[null_type])
# Out:
# Rows with null values in the 'year' column:
# Empty DataFrame
# Columns: [winery, wine, year, rating, num_reviews, country, region, price, type, body, acidity]
# Index: []

# %%
df_cleaned['country'] = df_cleaned['country'].fillna('Espana')

# Display the DataFrame after filling NaN values
print("\nDataFrame after renaming NaN values in 'country' to 'Espana':")
print(df_cleaned)
# Out:
# DataFrame after renaming NaN values in 'country' to 'Espana':
#                   winery             wine    year  rating  num_reviews  \
# 0          Teso La Monja            Tinto  2013.0     4.9           58
# 1                 Artadi    Vina El Pison  2018.0     4.9           31
# 2           Vega Sicilia            Unico  2009.0     4.8         1793
# 3           Vega Sicilia            Unico  1999.0     4.8         1705
# 4           Vega Sicilia            Unico  1996.0     4.8         1309
# ...                  ...              ...     ...     ...          ...
# 2046         Mustiguillo  Finca Terrerazo  2017.0     4.2          390
# 2047         Matarromera     Gran Reserva  2011.0     4.2          389
# 2048            Sei Solo         Preludio  2016.0     4.2          388
# 2049  Vinedos de Paganos       El Puntido  2005.0     4.2          384
# 6100   Remirez de Ganuza     Rioja Blanco  2017.0     4.2          421
#
# ...

# %%
unique_values = df_cleaned['rating'].unique()

# Display the unique values
print("\nUnique values in 'rating' column:")
print(unique_values)
# Out:
# Unique values in 'rating' column:
# [4.9 4.8 4.7 4.6 4.5 4.4 4.3 4.2]

# %%
null_type = df_cleaned['rating'].isnull()

# Display rows with null values in the 'type' column
print("\nRows with null values in the 'rating' column:")
print(df_cleaned[null_type])
# Out:
# Rows with null values in the 'rating' column:
# Empty DataFrame
# Columns: [winery, wine, year, rating, num_reviews, country, region, price, type, body, acidity]
# Index: []

# %%
df_cleaned['wineryID'] = df_cleaned.groupby('winery').ngroup()
# Out:
# /var/folders/ck/t8ktvnl92454zslcr12m5v9w0000gn/T/ipykernel_23098/3779131038.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['wineryID'] = df_cleaned.groupby('winery').ngroup()

# %%
df_cleaned['wineID'] = df_cleaned.groupby('wine').ngroup()
# Out:
# /var/folders/ck/t8ktvnl92454zslcr12m5v9w0000gn/T/ipykernel_23098/1192108819.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['wineID'] = df_cleaned.groupby('wine').ngroup()

# %%
df_cleaned['ratingID'] = df_cleaned.groupby('rating').ngroup()
# Out:
# /var/folders/ck/t8ktvnl92454zslcr12m5v9w0000gn/T/ipykernel_23098/1539282312.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['ratingID'] = df_cleaned.groupby('rating').ngroup()

# %%
print(df_cleaned.head())
# Out:
#           winery           wine    year  rating  num_reviews country  \
# 0  Teso La Monja          Tinto  2013.0     4.9           58  Espana
# 1         Artadi  Vina El Pison  2018.0     4.9           31  Espana
# 2   Vega Sicilia          Unico  2009.0     4.8         1793  Espana
# 3   Vega Sicilia          Unico  1999.0     4.8         1705  Espana
# 4   Vega Sicilia          Unico  1996.0     4.8         1309  Espana
#
#              region   price                  type body acidity  wineryID  \
# 0              Toro  995.00              Toro Red  5.0     3.0       422
# 1    Vino de Espana  313.50           Tempranillo  4.0     2.0        33
# 2  Ribera del Duero  324.95  Ribera Del Duero Red  5.0     3.0       447
# 3  Ribera del Duero  692.96  Ribera Del Duero Red  5.0     3.0       447
# 4  Ribera del Duero  778.06  Ribera Del Duero Red  5.0     3.0       447
#
#    wineID  ratingID
# 0     759         7
# 1     819         7
# 2     778         6
# 3     778         6
# ...

# %%
Winery = df_cleaned[['wineryID', 'wine', 'region']].copy()

print(Winery.head())
# Out:
#    wineryID           wine            region
# 0       422          Tinto              Toro
# 1        33  Vina El Pison    Vino de Espana
# 2       447          Unico  Ribera del Duero
# 3       447          Unico  Ribera del Duero
# 4       447          Unico  Ribera del Duero

# %%
Wine = df_cleaned[['wineID','wineryID', 'wine', 'year','type','body','acidity','price','num_reviews']].copy()

print(Wine.head())
# Out:
#    wineID  wineryID           wine    year                  type body acidity  \
# 0     759       422          Tinto  2013.0              Toro Red  5.0     3.0
# 1     819        33  Vina El Pison  2018.0           Tempranillo  4.0     2.0
# 2     778       447          Unico  2009.0  Ribera Del Duero Red  5.0     3.0
# 3     778       447          Unico  1999.0  Ribera Del Duero Red  5.0     3.0
# 4     778       447          Unico  1996.0  Ribera Del Duero Red  5.0     3.0
#
#     price  num_reviews
# 0  995.00           58
# 1  313.50           31
# 2  324.95         1793
# 3  692.96         1705
# 4  778.06         1309

# %%
Rating = df_cleaned[['ratingID', 'wineID']].copy()

print(Rating.head())
# Out:
#    ratingID  wineID
# 0         7     759
# 1         7     819
# 2         6     778
# 3         6     778
# 4         6     778

# %%
# Calculate average ratings per region
avg_ratings = df_cleaned.groupby('region')['rating'].mean().sort_values(ascending=False)

# Plot bar chart
plt.figure(figsize=(12, 6))
sns.barplot(x=avg_ratings.index, y=avg_ratings.values, palette='viridis')
plt.xticks(rotation=45, ha='right')
plt.title('Average Rating by Region')
plt.xlabel('Region')
plt.ylabel('Average Rating')
plt.tight_layout()
plt.show()
# Out:
# /var/folders/ck/t8ktvnl92454zslcr12m5v9w0000gn/T/ipykernel_23098/967370658.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=avg_ratings.index, y=avg_ratings.values, palette='viridis')

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_cleaned, x='price', y='rating', alpha=0.6)
plt.title('Rating vs. Price')
plt.xlabel('Price')
plt.ylabel('Rating')
plt.tight_layout()
plt.show()

# %%
# Group by year and calculate average rating
avg_rating_by_year = df_cleaned.groupby('year')['rating'].mean().sort_index()

# Plot
plt.figure(figsize=(10, 6))
sns.lineplot(x=avg_rating_by_year.index, y=avg_rating_by_year.values, marker='o')
plt.title('Average Rating by Year')
plt.xlabel('Year')
plt.ylabel('Average Rating')
plt.tight_layout()
plt.show()

# %%
avg_price_by_region = df_cleaned.groupby('region')['price'].mean().sort_values(ascending=False)

# Plot
plt.figure(figsize=(12, 6))
sns.barplot(x=avg_price_by_region.index, y=avg_price_by_region.values, palette='viridis')
plt.xticks(rotation=45, ha='right')
plt.title('Average Price by Region')
plt.xlabel('Region')
plt.ylabel('Average Price')
plt.tight_layout()
plt.show()
# Out:
# /var/folders/ck/t8ktvnl92454zslcr12m5v9w0000gn/T/ipykernel_23098/197564105.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=avg_price_by_region.index, y=avg_price_by_region.values, palette='viridis')

# %%
# Get top 30 wines by number of reviews
top_wines = df_cleaned.groupby('wine')['num_reviews'].sum().sort_values(ascending=False).head(30)

# Plot
plt.figure(figsize=(10, 6))
sns.barplot(x=top_wines.values, y=top_wines.index, palette='magma')
plt.title('Top 10 Most Reviewed Wines')
plt.xlabel('Number of Reviews')
plt.ylabel('Wine')
plt.tight_layout()
plt.show()
# Out:
# /var/folders/ck/t8ktvnl92454zslcr12m5v9w0000gn/T/ipykernel_23098/2685618657.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_wines.values, y=top_wines.index, palette='magma')

# %%
# Group by year and calculate average rating
avg_rating_by_year = df_cleaned.groupby('year')['rating'].mean().sort_index()

# Calculate overall average rating
overall_avg = df_cleaned['rating'].mean()

# Plot
plt.figure(figsize=(10, 6))
sns.lineplot(x=avg_rating_by_year.index, y=avg_rating_by_year.values, marker='o', label='Yearly Average')
plt.axhline(y=overall_avg, color='red', linestyle='--', label=f'Overall Average ({overall_avg:.2f})')
plt.ylim(0, max(avg_rating_by_year.values) + 1)  # Start y-axis at 0
plt.title('Average Rating by Year')
plt.xlabel('Year')
plt.ylabel('Average Rating')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Define custom price bins and labels
price_bins = [4.9, 50, 200, df_cleaned['price'].max()]
price_labels = ['4.90–50', '50–200', '200+']
df_cleaned['price_bin'] = pd.cut(df_cleaned['price'], bins=price_bins, labels=price_labels, include_lowest=True)

# Define custom rating bins and enforce desired order (4.6–4.9 on top)
rating_bins = [4.2, 4.5, 4.9]
rating_labels = ['4.2–4.5', '4.6–4.9']
df_cleaned['rating_bin'] = pd.cut(df_cleaned['rating'], bins=rating_bins, labels=rating_labels, include_lowest=True)

# Convert rating_bin to a categorical type with custom order
df_cleaned['rating_bin'] = pd.Categorical(df_cleaned['rating_bin'], categories=['4.6–4.9', '4.2–4.5'], ordered=True)

# Create pivot table
heatmap_data = df_cleaned.pivot_table(
    values='num_reviews',
    index='rating_bin',
    columns='price_bin',
    aggfunc='mean'  # or 'sum' if desired
)

# Plot heatmap
plt.figure(figsize=(12, 6))
sns.heatmap(heatmap_data, cmap='YlOrRd', annot=True, fmt=".0f", linewidths=0.5)

plt.title('Heatmap of Average Number of Reviews by Rating and Price Range')
plt.xlabel('Price Range (€)')
plt.ylabel('Rating Range')
plt.tight_layout()
plt.show()
# Out:
# /var/folders/ck/t8ktvnl92454zslcr12m5v9w0000gn/T/ipykernel_23098/2963020097.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['price_bin'] = pd.cut(df_cleaned['price'], bins=price_bins, labels=price_labels, include_lowest=True)
# /var/folders/ck/t8ktvnl92454zslcr12m5v9w0000gn/T/ipykernel_23098/2963020097.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['rating_bin'] = pd.cut(df_cleaned['rating'], bins=rating_bins, labels=rating_labels, include_lowest=True)
# ...

# %%
import scipy.stats as stats

# Perform Chi-Square Test
chi2, p, dof, expected = stats.chi2_contingency(heatmap_data.fillna(0))

# Display results
print(f"Chi-Square Statistic: {chi2:.2f}")
print(f"Degrees of Freedom: {dof}")
print(f"P-Value: {p:.4f}")

# Interpretation
if p < 0.05:
    print("There is a statistically significant association between rating and price bins.")
else:
    print("No significant association between rating and price bins.")
# Out:
# Chi-Square Statistic: 552.94
# Degrees of Freedom: 2
# P-Value: 0.0000
# There is a statistically significant association between rating and price bins.

# %%
# Define the price ranges and required counts
price_ranges = [(20, 50, 1), (50, 100, 2), (100, 150, 3), (150, 250, 4), (250, float('inf'), 5)]

# Create an empty list to store selected wines
selected_wines = []

# Loop through each price range and select the top wines
for min_price, max_price, count in price_ranges:
    wines_in_range = df_cleaned[(df_cleaned['rating'] > 4.5) & (df_cleaned['price'].between(min_price, max_price))]
    top_wines = wines_in_range.nlargest(count, 'num_reviews')
    selected_wines.append(top_wines)

# Concatenate all selections into a single dataframe
final_selection = pd.concat(selected_wines)[['wine', 'rating', 'num_reviews', 'price']]

# Display the result
print(final_selection)
# Out:
#                                           wine  rating  num_reviews  \
# 176                         Pago De Valtarrena     4.6          700
# 164                           Ribera del Duero     4.6         4516
# 166  PS (Pagos Seleccionados) Ribera del Duero     4.6         3239
# 162                                Valbuena 5o     4.6         4747
# 165  PS (Pagos Seleccionados) Ribera del Duero     4.6         3383
# 58                                 Valbuena 5o     4.7         2177
# 158                                Valbuena 5o     4.6         6803
# 159                                Valbuena 5o     4.6         5938
# 160                                Valbuena 5o     4.6         5545
# 47                                 Valbuena 5o     4.7         5266
# 46              Unico Reserva Especial Edicion     4.7        12421
# 50                                       Unico     4.7         3437
# 51                                       Unico     4.7         3164
# ...

# %%
# Define the price ranges and required counts
price_ranges = [(20, 50, 1), (50, 100, 2), (100, 150, 3), (150, 250, 4), (250, float('inf'), 5)]

# Create an empty list to store selected wines
selected_wines = []

# Loop through each price range and select the top wines
for min_price, max_price, count in price_ranges:
    wines_in_range = df_cleaned[(df_cleaned['rating'] > 4.5) & (df_cleaned['price'].between(min_price, max_price))]
    top_wines = wines_in_range.nlargest(count, 'num_reviews')
    selected_wines.append(top_wines)

# Concatenate all selections into a single dataframe
final_selection = pd.concat(selected_wines)[['wine', 'rating', 'num_reviews', 'price']]

# Remove duplicates, keeping only the one with the highest number of reviews per wine name
final_selection = final_selection.sort_values('num_reviews', ascending=False).drop_duplicates(subset='wine', keep='first')

# Ensure that exactly 5 wines are selected while keeping the price range logic
final_list = pd.DataFrame()
for min_price, max_price, _ in price_ranges:
    wine_in_range = final_selection[final_selection['price'].between(min_price, max_price)]
    if not wine_in_range.empty:
        final_list = pd.concat([final_list, wine_in_range.head(1)])  # Pick the highest-reviewed wine in the range

# Display the result
print(final_list)
# Out:
#                                           wine  rating  num_reviews  \
# 176                         Pago De Valtarrena     4.6          700
# 164                           Ribera del Duero     4.6         4516
# 165  PS (Pagos Seleccionados) Ribera del Duero     4.6         3383
# 158                                Valbuena 5o     4.6         6803
# 46              Unico Reserva Especial Edicion     4.7        12421
#
#           price
# 176   49.950000
# 164   79.800000
# 165  116.187944
# 158  218.000000
# 46   423.500000

# %%
# Define the price ranges and required counts
price_ranges = [(20, 50, 1), (50, 100, 2), (100, 150, 3), (150, 250, 4), (250, float('inf'), 5)]

# Create an empty list to store selected wines
selected_wines = []

# Loop through each price range and select the top wines
for min_price, max_price, count in price_ranges:
    wines_in_range = df_cleaned[
        (df_cleaned['rating'] > 4.5) & 
        (df_cleaned['price'].between(min_price, max_price))
    ]
    
    top_wines = wines_in_range.nlargest(count, 'num_reviews')
    
    # Ensure winery and region are included in the selection
    selected_wines.append(top_wines[['wine', 'winery', 'region', 'rating', 'num_reviews', 'price']])

# Concatenate all selections into a single dataframe
final_selection = pd.concat(selected_wines)

# Remove duplicates, keeping only the one with the highest number of reviews per wine
final_selection = final_selection.sort_values('num_reviews', ascending=False).drop_duplicates(subset='wine', keep='first')

# Ensure that exactly 5 wines are selected while keeping the price range logic
final_list = []
for min_price, max_price, _ in price_ranges:
    wine_in_range = final_selection[final_selection['price'].between(min_price, max_price)]
    if not wine_in_range.empty:
        final_list.append(wine_in_range.head(1))  # Pick the highest-reviewed wine in the range

# Convert list to DataFrame
final_list = pd.concat(final_list)

# Display the final result
print(final_list)
# Out:
#                                           wine          winery  \
# 176                         Pago De Valtarrena  Carmelo Rodero
# 164                           Ribera del Duero           Alion
# 165  PS (Pagos Seleccionados) Ribera del Duero           Aalto
# 158                                Valbuena 5o    Vega Sicilia
# 46              Unico Reserva Especial Edicion    Vega Sicilia
#
#                region  rating  num_reviews       price
# 176  Ribera del Duero     4.6          700   49.950000
# 164  Ribera del Duero     4.6         4516   79.800000
# 165  Ribera del Duero     4.6         3383  116.187944
# 158  Ribera del Duero     4.6         6803  218.000000
# 46   Ribera del Duero     4.7        12421  423.500000

# %%
# Define price ranges and labels
price_ranges = [(20, 50), (50, 100), (100, 150), (150, 250), (250, float('inf'))]
price_labels = ['€20-50', '€50-100', '€100-150', '€150-250', '€250+']

# Calculate average number of reviews for each price range
avg_reviews = []
selected_wine_reviews = []
for (min_price, max_price), label in zip(price_ranges, price_labels):
    subset = df_cleaned[df_cleaned['price'].between(min_price, max_price)]
    avg_reviews.append(subset['num_reviews'].mean())

    # Find selected wine in this range
    selected_wine = final_list[final_list['price'].between(min_price, max_price)]
    if not selected_wine.empty:
        selected_wine_reviews.append(selected_wine.iloc[0]['num_reviews'])
    else:
        selected_wine_reviews.append(0)  # Assign 0 if no wine selected in this range

# Convert to DataFrame
comparison_df = pd.DataFrame({'Selected Wine Reviews': selected_wine_reviews, 'Avg Num Reviews': avg_reviews}, index=price_labels)

# Define bar width
bar_width = 0.4
x_labels = np.arange(len(price_labels))

# Create figure
fig, ax = plt.subplots(figsize=(10, 6))

# Plot grouped bars
ax.bar(x_labels - bar_width/2, comparison_df['Selected Wine Reviews'], bar_width, color='green', label='Wine Reviews')
ax.bar(x_labels + bar_width/2, comparison_df['Avg Num Reviews'], bar_width, color='darkgreen', label='Avg Reviews')

ax.set_ylabel('Number of Reviews')
ax.set_xticks(x_labels)
ax.set_xticklabels(price_labels, rotation=45, ha='right')

# Add legend
ax.legend(loc='upper left')

# Improve layout
plt.title('Comparison of Selected Wine Reviews vs Price Range Average')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# %%
# Define price ranges and labels
price_ranges = [(20, 50), (50, 100), (100, 150), (150, 250), (250, float('inf'))]
price_labels = ['€20-50', '€50-100', '€100-150', '€150-250', '€250+']

# Calculate average ratings for each price range
avg_ratings = []
selected_wine_ratings = []
for (min_price, max_price), label in zip(price_ranges, price_labels):
    subset = df_cleaned[df_cleaned['price'].between(min_price, max_price)]
    avg_ratings.append(subset['rating'].mean())

    # Find selected wine in this range
    selected_wine = final_list[final_list['price'].between(min_price, max_price)]
    if not selected_wine.empty:
        selected_wine_ratings.append(selected_wine.iloc[0]['rating'])
    else:
        selected_wine_ratings.append(0)  # Assign 0 if no wine selected in this range

# Convert to DataFrame
comparison_df = pd.DataFrame({'Selected Wine Rating': selected_wine_ratings, 'Avg Rating': avg_ratings}, index=price_labels)

# Define bar width
bar_width = 0.4
x_labels = np.arange(len(price_labels))

# Create figure
fig, ax = plt.subplots(figsize=(10, 6))

# Plot grouped bars
ax.bar(x_labels - bar_width/2, comparison_df['Selected Wine Rating'], bar_width, color='red', label='Wine Rating')
ax.bar(x_labels + bar_width/2, comparison_df['Avg Rating'], bar_width, color='darkred', label='Avg Rating')

ax.set_ylabel('Rating')
ax.set_xticks(x_labels)
ax.set_xticklabels(price_labels, rotation=45, ha='right')

# Add legend
ax.legend(loc='upper left')

# Improve layout
plt.title('Comparison of Selected Wine Rating vs Price Range Average')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()
